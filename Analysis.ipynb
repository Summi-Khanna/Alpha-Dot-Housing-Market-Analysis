# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
geocode_df = pd.read_csv(Path("./Resources/wa_county_geocodes.csv"))
geocode_df.head()
# Out:
#   USPS  GEOID  ANSICODE     NAME       ALAND      AWATER  ALAND_SQMI  \
# 0   WA  53001   1531601    Adams  4985698856    12464425    1924.989
# 1   WA  53003   1533502   Asotin  1647427905    11291731     636.075
# 2   WA  53005   1513302   Benton  4403309851   154293639    1700.128
# 3   WA  53007   1531932   Chelan  7565814941   189653434    2921.178
# 4   WA  53009   1531341  Clallam  4503412739  2409309960    1738.777
#
#    AWATER_SQMI   INTPTLAT   INTPTLONG
# 0        4.813  47.011238 -118.512861
# 1        4.360  46.181861 -117.227781
# 2       59.573  46.228125 -119.516659
# 3       73.226  47.860974 -120.619041
# 4      930.240  48.110903 -123.889860

# %%
wa_house_listings_df = pd.read_csv(Path("./Resources/wa_house_listing.csv"))
wa_house_listings_df.head()
# Out:
#    Unnamed: 0        Date  county_fips county_name  median_listing_price  \
# 0           0  2016-07-01        53001       Adams              125000.0
# 1           1  2016-07-01        53003      Asotin              220000.0
# 2           2  2016-07-01        53005      Benton              286500.0
# 3           3  2016-07-01        53007      Chelan              394000.0
# 4           4  2016-07-01        53009     Clallam              325000.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                      NaN                      NaN                    34
# 1                      NaN                      NaN                   120
# 2                      NaN                      NaN                   629
# 3                      NaN                      NaN                   502
# 4                      NaN                      NaN                   596
#
#    active_listing_count_mm  active_listing_count_yy  ...  \
# ...

# %%
#Check for null values
wa_house_listings_df.isnull().sum()

# %%
wa_house_listings_df.describe()

# %%
wa_house_listings_geo = pd.merge(left = wa_house_listings_df, right=geocode_df, left_on='county_fips', right_on='GEOID')

# %%
wa_house_listings_geo
# Out:
#       Unnamed: 0        Date  county_fips county_name  median_listing_price  \
# 0              0  2016-07-01        53001       Adams              125000.0
# 1             39  2016-08-01        53001       Adams              125000.0
# 2             78  2016-09-01        53001       Adams              134997.0
# 3            117  2016-10-01        53001       Adams              141500.0
# 4            156  2016-11-01        53001       Adams              149000.0
# ...          ...         ...          ...         ...                   ...
# 2568        2416  2021-08-01        53077      Yakima              357450.0
# 2569        2455  2021-09-01        53077      Yakima              369925.0
# 2570        2494  2021-10-01        53077      Yakima              370000.0
# 2571        2533  2021-11-01        53077      Yakima              387450.0
# 2572        2572  2021-12-01        53077      Yakima              384750.0
#
# ...
